# %%
import os
import pandas as pd
from tqdm import tqdm

# %%
current_path = os.getcwd()
current_path = current_path.split('movie-pre-buzz-to-box-office')
path = current_path[0] + 'movie-pre-buzz-to-box-office'
path
# Out:
# '/Users/drknt_rises/Desktop/Personal/Git Repos/movie-pre-buzz-to-box-office'

# %%
videoIds = pd.read_csv(path + "/Data/Trailer Ids/youtube trailer Ids.csv")
videoIds
# Out:
#                                              Url     Video Id
# 0    https://www.youtube.com/watch?v=FvQ8ieRAySY  FvQ8ieRAySY
# 1    https://www.youtube.com/watch?v=uYPbbksJxIg  uYPbbksJxIg
# 2    https://www.youtube.com/watch?v=bRDuc3IdOn8  bRDuc3IdOn8
# 3    https://www.youtube.com/watch?v=AHmCH7iB_IM  AHmCH7iB_IM
# 4    https://www.youtube.com/watch?v=yP4puq7dgC4  yP4puq7dgC4
# ..                                           ...          ...
# 490  https://www.youtube.com/watch?v=-Denciie5oA  -Denciie5oA
# 491  https://www.youtube.com/watch?v=XFYWazblaUA  XFYWazblaUA
# 492  https://www.youtube.com/watch?v=nrXlY6gzTTM  nrXlY6gzTTM
# 493  https://www.youtube.com/watch?v=fm_zzAMuvyQ  fm_zzAMuvyQ
# 494  https://www.youtube.com/watch?v=yDEjsLFe_7w  yDEjsLFe_7w
#
# [495 rows x 2 columns]

# %%
def videoDetails(videoId, apiKey):
    import googleapiclient.discovery
    import googleapiclient.errors

    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

    api_service_name = "youtube"
    api_version = "v3"
    credentials = apiKey
    
    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey=credentials)

    request = youtube.videos().list(
        part="snippet,contentDetails,statistics", 
        id=videoId
    )
    response = request.execute()

    return response

# %%
videoIds = list(videoIds['Video Id'])
key = input("Enter the API Key:")
for i in tqdm(range(len(videoIds))):
    data = []
    row=[]
    row.append(videoIds[i])
    response = videoDetails(videoIds[i], apiKey=key)

    try: 
        row.append(response['etag']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['snippet']['publishedAt']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['snippet']['title']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['snippet']['description']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['snippet']['channelTitle']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['snippet']['categoryId']) 
    except KeyError: 
        row.append(None)

    try:
        row.append(response['items'][0]['snippet']['defaultAudioLanguage'])
    except KeyError:
        row.append(None)
    
    try:
        row.append(response['items'][0]['contentDetails']['duration']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['contentDetails']['definition']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['contentDetails']['caption']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['contentDetails']['licensedContent']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['statistics']['viewCount']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['statistics']['likeCount']) 
    except KeyError: 
        row.append(None)
    
    try:
        row.append(response['items'][0]['statistics']['commentCount'])
    except KeyError: 
        row.append(None)
    
    data.append(row)

    cols = ['videoId', 'etag', 'publishedAt', 'title', 'description', 'channelTitle', 'categoryId', \
            'defaultAudioLanguage', 'duration', 'definition', 'caption', 'licensedContent', \
                'viewCount', 'likeCount', 'commentCount'] 
    data = pd.DataFrame(data, columns=cols)
    
    if i==0:
        data.to_csv(path + '/Data/Real Data/videoDescription.csv', index=False, header=True)
    else:
        data.to_csv(path + '/Data/Real Data/videoDescription.csv', mode='a', index=False, header=False)
# Out:
# 100%|██████████| 495/495 [01:37<00:00,  5.07it/s]

# %%
pd.read_csv(path + '/Data/Real Data/videoDescription.csv')
# Out:
#          videoId                         etag           publishedAt  \
# 0    FvQ8ieRAySY  u0boKldbkl1jfJnY-_aG3nOTeWA  2021-06-03T02:48:34Z
# 1    uYPbbksJxIg  6mRZPlT-C9mkRnQb-CUfiIj9nF4  2023-05-08T07:01:04Z
# 2    bRDuc3IdOn8  mFgXKUjRIaMAqSkD2jQWWdmAktA  2020-02-26T15:06:52Z
# 3    AHmCH7iB_IM  0wqVRSOA4Crc2GWsLjo5LChNmzQ  2022-10-18T15:59:00Z
# 4    yP4puq7dgC4  D273oIbiEAcTnZo_0yoDT91gfFA  2019-11-14T17:17:08Z
# ..           ...                          ...                   ...
# 490  -Denciie5oA  DGvFDoEA6-ma7UtFQNoa5plLbvY  2017-10-19T17:14:24Z
# 491  XFYWazblaUA  YbGTudocgv-NpdPTzXdujJa_FSQ  2017-07-19T13:59:40Z
# 492  nrXlY6gzTTM  73gpTBBIBBvS_nioHhtPLAxIR2A  2017-11-08T05:31:00Z
# 493  fm_zzAMuvyQ  UwuzkcLaGjRR6TL0WFaDOQbDX6M  2018-01-10T22:15:46Z
# 494  yDEjsLFe_7w  4EiBdB0mUc8BX4RXjA2AoN0Dbzc  2018-02-09T05:01:06Z
#
#                                                  title  \
# 0                             Love by Drowning Trailer
# 1                            Oppenheimer | New Trailer
# 2    The Painted Bird - Official Trailer I HD I IFC...
# 3                         CREED III | Official Trailer
# 4    Goldie (2019) | Official U.S. Trailer | Slick ...
# ..                                                 ...
# 490                       12 STRONG - Official Trailer
# 491  THE SHAPE OF WATER | Official Trailer | FOX Se...
# 492  The Post | Official Trailer [HD] | 20th Centur...
# 493  I Can Only Imagine Official Trailer | In theat...
# 494  Fifty Shades Freed | Trailer | Own it now on D...
#
#                                            description  \
# 0                                                  NaN
# 1    Oppenheimer - In Theaters 7 21 23\n\nWritten a...
# 2    Opening April 17th in theaters\n\nDirected by:...
# 3    There’s no enemy like the past. From director ...
# 4    Goldie (Slick Woods) is a star – well, not qui...
# ..                                                 ...
# 490  On September 11, 2001, the world watched in te...
# 491  Now On Digital: http://bit.ly/ShapeOfWater-Dig...
# 492  Now On Digital: http://bit.ly/ThePostDigital\n...
# 493  It’s the song that brings ultimate hope to so ...
# 494  Subscribe to Our Channel: http://uni.pictures/...
#
#                       channelTitle  categoryId defaultAudioLanguage duration  \
# 0       Love By Drowning The Movie           1                en-US  PT1M37S
# 1               Universal Pictures          24                   en   PT3M7S
# 2                        IFC Films           1                   en  PT2M38S
# 3                              MGM          24                en-US  PT2M24S
# 4                    Film Movement           1                  NaN  PT1M36S
# ..                             ...         ...                  ...      ...
# 490          Warner Bros. Pictures          24                   en  PT2M45S
# 491            SearchlightPictures           1                en-US  PT2M31S
# 492           20th Century Studios           1                   en  PT2M33S
# 493                   RoadsideFlix           1                  NaN  PT2M21S
# 494  Universal Pictures All-Access          44                   en   PT2M7S
#
#     definition  caption  licensedContent  viewCount  likeCount  commentCount
# 0           hd    False            False        523        NaN           NaN
# 1           hd     True             True   63307575   785382.0       31831.0
# 2           hd    False             True     730328     3195.0         412.0
# 3           hd     True             True   18332408   198363.0       11032.0
# 4           hd    False             True     122923      407.0          33.0
# ..         ...      ...              ...        ...        ...           ...
# 490         hd    False             True   17963171   120615.0        6940.0
# 491         hd    False             True   26530341   139164.0        9740.0
# 492         hd    False             True   18163235    24408.0        2815.0
# 493         hd    False            False     506432     3765.0          67.0
# 494         hd    False             True     233140        NaN           0.0
#
# [495 rows x 15 columns]
